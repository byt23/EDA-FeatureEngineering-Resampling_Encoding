# %% [markdown]
# NumPy - Pandas - Matplotlib - Seaborn - EDA - Feature Engineering - Resampling - Encoding

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.isnull()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df["bmi"].unique()
# Out:
# array([36.6,  nan, 32.5, 34.4, 24. , 29. , 27.4, 22.8, 24.2, 29.7, 36.8,
#        27.3, 28.2, 30.9, 37.5, 25.8, 37.8, 22.4, 48.9, 26.6, 27.2, 23.5,
#        28.3, 44.2, 25.4, 22.2, 30.5, 26.5, 33.7, 23.1, 32. , 29.9, 23.9,
#        28.5, 26.4, 20.2, 33.6, 38.6, 39.2, 27.7, 31.4, 36.5, 33.2, 32.8,
#        40.4, 25.3, 30.2, 47.5, 20.3, 30. , 28.9, 28.1, 31.1, 21.7, 27. ,
#        24.1, 45.9, 44.1, 22.9, 29.1, 32.3, 41.1, 25.6, 29.8, 26.3, 26.2,
#        29.4, 24.4, 28. , 28.8, 34.6, 19.4, 30.3, 41.5, 22.6, 56.6, 27.1,
#        31.3, 31. , 31.7, 35.8, 28.4, 20.1, 26.7, 38.7, 34.9, 25. , 23.8,
#        21.8, 27.5, 24.6, 32.9, 26.1, 31.9, 34.1, 36.9, 37.3, 45.7, 34.2,
#        23.6, 22.3, 37.1, 45. , 25.5, 30.8, 37.4, 34.5, 27.9, 29.5, 46. ,
#        42.5, 35.5, 26.9, 45.5, 31.5, 33. , 23.4, 30.7, 20.5, 21.5, 40. ,
#        28.6, 42.2, 29.6, 35.4, 16.9, 26.8, 39.3, 32.6, 35.9, 21.2, 42.4,
#        40.5, 36.7, 29.3, 19.6, 18. , 17.6, 19.1, 50.1, 17.7, 54.6, 35. ,
# ...

# %%
df.dropna().shape
# Out:
# (4909, 12)

# %%
df.dropna(axis=1)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   smoking_status  stroke
# ...

# %%
df["bmi"].value_counts()
# Out:
# bmi
# 28.7    41
# 28.4    38
# 26.7    37
# 27.6    37
# 26.1    37
#         ..
# 48.7     1
# 49.2     1
# 51.0     1
# 49.4     1
# 14.9     1
# Name: count, Length: 418, dtype: int64

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df[["work_type"]].value_counts()
# Out:
# work_type
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
df[["Residence_type"]].value_counts()
# Out:
# Residence_type
# Urban             2596
# Rural             2514
# Name: count, dtype: int64

# %%
df[["smoking_status"]].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
null_bmi = df["bmi"].isna().sum()
null_bmi
# Out:
# np.int64(201)

# %%
total_value_bmi = df["bmi"].sum()
total_value_bmi
# Out:
# np.float64(141836.90000000002)

# %%
total_bmi = df["bmi"].value_counts().sum()
total_bmi
# Out:
# np.int64(4909)

# %%
average_bmi = total_value_bmi / total_bmi 
average_bmi
# Out:
# np.float64(28.893236911794666)

# %%
df["bmi_mean"] = df["bmi"].fillna(df["bmi"].mean())

# %%
df["bmi_median"] = df["bmi"].fillna(df["bmi"].median())

# %%
df[["bmi_median","bmi_mean","bmi"]]
# Out:
#       bmi_median   bmi_mean   bmi
# 0           36.6  36.600000  36.6
# 1           28.1  28.893237   NaN
# 2           32.5  32.500000  32.5
# 3           34.4  34.400000  34.4
# 4           24.0  24.000000  24.0
# ...          ...        ...   ...
# 5105        28.1  28.893237   NaN
# 5106        40.0  40.000000  40.0
# 5107        30.6  30.600000  30.6
# 5108        25.6  25.600000  25.6
# 5109        26.2  26.200000  26.2
#
# [5110 rows x 3 columns]

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
sns.boxplot(data = df, y = "bmi_mean")
# Out:
# <Axes: ylabel='bmi_mean'>

# %%
sns.boxplot(data = df, y = "bmi_median")
# Out:
# <Axes: ylabel='bmi_median'>

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# bmi_mean               0
# bmi_median             0
# dtype: int64

# %%
df_clean = df.copy()

# %%
df_clean.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# bmi_mean               0
# bmi_median             0
# dtype: int64

# %%
df_clean["bmi"] = df_clean["bmi_mean"]

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# bmi_mean             0
# bmi_median           0
# dtype: int64

# %%
plt.scatter("bmi","avg_glucose_level", data = df_clean, color = "g")
plt.xlabel("Body Mass Index")
plt.ylabel("Average Glucose Level")
plt.title("BMI vs Glucose Comparision Graph")
plt.show()

# %%
df_clean2 = df.copy()

# %%
df_clean2["bmi"] = df_clean["bmi_median"]

# %%
plt.scatter("bmi","avg_glucose_level", data = df_clean2, color = "b")
plt.xlabel("Body Mass Index")
plt.ylabel("Average Glucose Level")
plt.title("BMI vs Glucose Comparision Graph")
plt.show()

# %%
df_clean
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "bmi", y = "avg_glucose_level", data=df_clean2, hue = "gender", palette = "mako")
plt.xlabel("Body Mass Index")
plt.ylabel("Average Glucose Level")
plt.title("BMI vs Glucose Comparision Graph")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "bmi", y = "avg_glucose_level", data=df_clean2, hue = "Residence_type", palette = "rocket")
plt.xlabel("Body Mass Index")
plt.ylabel("Average Glucose Level")
plt.title("BMI vs Glucose Comparision Graph")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "bmi", y = "avg_glucose_level", data=df_clean2, hue = "gender", palette = "bright")
plt.xlabel("Body Mass Index")
plt.ylabel("Average Glucose Level")
plt.title("BMI vs Glucose Comparision Graph")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "bmi", y = "avg_glucose_level", data=df_clean2, hue = "gender", palette = "icefire", style = "ever_married")
plt.xlabel("Body Mass Index")
plt.ylabel("Average Glucose Level")
plt.title("BMI vs Glucose Comparision Graph")
plt.show()

# %%
sns.barplot(x = "hypertension", y = "heart_disease" , hue = "gender",  data=df_clean2, palette="flare")
plt.title("Hypertension and Heart disease Graph by Gender")
plt.xlabel("Hypertension")
plt.ylabel("Heart Disease")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
#  12  bmi_mean           5110 non-null   float64
#  13  bmi_median         5110 non-null   float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 559.0+ KB
